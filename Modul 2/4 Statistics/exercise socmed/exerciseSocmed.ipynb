# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('dataSocmed.csv',)
data.head()
# Out:
#      Month      Date Profile Name    Channel Content Type  Likes  Comments
# 0  Januari  1/1/2019    Orange_id  INSTAGRAM     carousel  282.0       4.0  \
# 1  Januari  1/2/2019    Orange_id  INSTAGRAM        video  158.0       2.0
# 2  Januari  1/3/2019    Orange_id  INSTAGRAM     carousel  346.0      11.0
# 3  Januari  1/4/2019    Orange_id  INSTAGRAM     carousel  197.0       1.0
# 4  Januari  1/8/2019    Orange_id  INSTAGRAM     carousel  674.0      15.0
#
#     Labels Interactions Insights - Reach Insights - Impressions
# 0  ORGANIC          286            3,732                  7,367  \
# 1  ORGANIC          160            3,407                  4,696
# 2  ORGANIC          357            4,607                  8,526
# 3  ORGANIC          198            3,412                  6,446
# 4  ORGANIC          689            9,156                 15,817
#
#    Insights - Saves Insights - Engagement Insights - Video Views
# ...
