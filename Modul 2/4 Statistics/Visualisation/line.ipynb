# %% [markdown]
# # **DATA VISUALIZATION**
#
# **Outline :**
# 1. Histogram
# 2. Boxplot
# 3. Line Plot
# 4. Scatterplot
#
# **Libraries Requirements :**
# - Matplotlib
# - Pandas
# - Seaborn
#
# **Dataset : Global Superstore (On Discord)**

# %%
# Library

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Load Data

df = pd.read_csv('Sample_Superstore.csv',encoding='unicode_escape')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520  \
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...
# 0      Claire Gute   Consumer  United States        Henderson  ...  \
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category
# ...

# %%
# Info 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
# Descriptive Stat 

df.describe(include='all')
# Out:
#              Row ID        Order ID Order Date   Ship Date       Ship Mode
# count   9994.000000            9994       9994        9994            9994  \
# unique          NaN            5009       1237        1334               4
# top             NaN  CA-2017-100111   9/5/2016  12/16/2015  Standard Class
# freq            NaN              14         38          35            5968
# mean    4997.500000             NaN        NaN         NaN             NaN
# std     2885.163629             NaN        NaN         NaN             NaN
# min        1.000000             NaN        NaN         NaN             NaN
# 25%     2499.250000             NaN        NaN         NaN             NaN
# 50%     4997.500000             NaN        NaN         NaN             NaN
# 75%     7495.750000             NaN        NaN         NaN             NaN
# max     9994.000000             NaN        NaN         NaN             NaN
#
# ...

# %%
# Cleaning Sementara (Remove Outliers)

df_clean = df[df['Profit'].between(-250, 250)]
df_clean.shape
# Out:
# (9551, 21)

# %% [markdown]
# # **1. LINE PLOT**
# ___
#
# catatan:
# 1. Digunakan untuk merepresentasikan data **TIME SERIES** atau rentan waktu tertentu.
# 2. Sumbu X adalah data rentan waktu dan Y adalah nilai yang ingin ditampilkan
# 3. Bivariate (2 Variable): Numerical Vs Time Series

# %% [markdown]
# ## **a. Data Time Series**

# %%
#df_clean.info() #cek terlebih dahulu field time apakah sudah menjadi tipe datanya 'DATE'?

df_clean['Order Date'] = pd.to_datetime(df_clean['Order Date'])
df_clean['Ship Date'] = pd.to_datetime(df_clean['Ship Date'])
#df_clean.info()

df_clean['Order Month'] = df_clean['Order Date'].apply(lambda x : str(x)[:7])
df_clean['Order Month'] = pd.to_datetime(df_clean['Order Month'])
df_clean['Order Month Name'] = df_clean['Order Date'].dt.month_name()
display(df_clean.head()) #tanggal akan terisi otomatis di tanggal yang sama. hal ini dimaksudkan untuk memplotting sumbu x agar sama

df_cleanSales = df_clean.groupby('Order Month')['Sales'].mean().reset_index()
df_cleanSales.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520  \
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...
# 0      Claire Gute   Consumer  United States        Henderson  ...  \
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 5  Brosina Hoffman   Consumer  United States      Los Angeles  ...
#
#         Product ID         Category Sub-Category
# 0  FUR-BO-10001798        Furniture    Bookcases  \
# ...

# %%
plt.figure(figsize=(15,5))


plt.plot(
    df_cleanSales['Order Month'],
    df_cleanSales['Sales']
)

plt.title('Rata rata penjualan setiap bulan (2016-2019)',size=15)
plt.xticks(df_cleanSales['Order Month'],rotation = 90)
plt.show()

# %% [markdown]
# ## **c. Seaborn**

# %%
plt.figure(figsize=(15,5))
sns.set_style('darkgrid')

sns.lineplot(
    data = df_clean,
    x = 'Order Month',
    y = 'Sales'
)
plt.title('Rata rata penjualan setiap bulan (2016-2019)',size=15)
plt.xticks(df_cleanSales['Order Month'],rotation = 90)
plt.show()

# %%
# CEK UPPER LOWER 

print('Rumus confidence interval = Mean -+ 1.96 * Standard Error\n')

mean = df_clean[df_clean['Order Month'] == '2014-01-01' ]['Sales'].mean()
se = df_clean[df_clean['Order Month'] == '2014-01-01' ]['Sales'].sem() * 1.96
bound = (mean-se,mean+se)

print(f'Nilai Mean\t:{mean}')
print(f'Nilai SE\t:{se}')
print(f'Nilai Lower Bound\t:{bound[0]}')
print(f'Nilai Upper Bound\t:{bound[1]}')
# Out:
# Rumus confidence interval = Mean -+ 1.96 * Standard Error
#
# Nilai Mean	:136.33180000000002
# Nilai SE	:54.92893395660325
# Nilai Lower Bound	:81.40286604339676
# Nilai Upper Bound	:191.26073395660327

# %%
#BUAT 2 LINE PLOT

plt.figure(figsize=(15,5))
sns.set_style('darkgrid')

#LINE 1
sns.lineplot(
    data = df_clean[df_clean['Order Month Name']=='January'],
    x = 'Order Month',
    y = 'Sales',
    label = 'January'
)

#LINE 2
sns.lineplot(
    data = df_clean[df_clean['Order Month Name']=='February'],
    x = 'Order Month',
    y = 'Sales',
    label = 'February'
)


plt.title('Rata rata penjualan setiap bulan (2016-2019)',size=15)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## **d. Pandas**

# %%
df_cleanSales.plot(x='Order Month', y='Sales')
# Out:
# <Axes: xlabel='Order Month'>

# %% [markdown]
# # **2. SCATTERPLOT**
# ---
# Catatan:
# 1. Digunakan untuk melihat hubungan **2 VARIABLE/COLUMN** yang berjenis numerical
# 2. Bivariate (2 Variable): Numerical vs Numerical
# 3. Terkadang dapat melihat outliers

# %%
plt.figure(figsize=(10,10))

sns.scatterplot(x = 'Sales', y = 'Profit', data = df_clean, hue = 'Category')

plt.title('Sales vs Profit, size = 15')
plt.xlabel('Sales', size=10)
plt.ylabel('Sales',size=10)
plt.show()

# %%
corr = df_clean['Sales'].corr(df_clean['Profit'])
corr
# Out:
# 0.3861713028537551

# %% [markdown]
# # **3. BAR PLOT**
#
# ---
#
# 1. Membandingkan nilai (numerical) antara 2 kelompok/kategori atau lebih.
# 2. Nilai yang dibandingkan bisa berupa frequency (count), mean, medianm sum, dll.
# 3. BiVariate (2 Variabel) Categorical vs Numerical

# %% [markdown]
# # **Analisis 1: Menampilkan rata-rata Sales untuk setiap Category**

# %%
plt.figure()
sns.barplot(data = df_clean,x='Category', y='Sales', estimator = np.mean, ci=0)
plt.title('Rata-rata Sales per Caategory')
plt.show()

plt.figure()
sns.barplot(data = df_clean,x='Sales', y='Category', estimator = np.mean, ci=0)
plt.title('Rata-rata Sales per Caategory')
plt.show()

# %% [markdown]
# # **Analisis 2: Jumlah transaksi berdasarkan Segment**

# %%
plt.figure()

sns.barplot(
    data = df_clean,
    x = 'Segment',
    y = 'Sales',
    estimator= len,
    ci=0
)

plt.title('Number of Transaction by Segment')
plt.show()

# %%
plt.figure()

sns.histplot(
    data = df_clean['Segment'],
    # x = 'Segment',
    # y = 'Sales',
    # estimator= len,
    # ci=0
)

plt.title('Number of Transaction by Segment')
plt.show()

# %%
plt.figure()

sns.countplot(
    data = df_clean,
    x = 'Segment'
    # hue = 'Category'
)

plt.title('Number of Transaction by Segment')
plt.show()

# %%
plt.figure()

sns.countplot(
    data = df_clean,
    y = 'Segment',
    hue = 'Category'
)

plt.xlabel('we')
plt.title('Number of Transaction by Segment')
plt.show()

# %% [markdown]
# ## **4. PIE CHART**
# ---
# Catatan:
# 1. Menggambarkan proporsi/persentase dari sebuah kategori/kelompok.
# 2. Bivariate (Kategori Vs Numerical) biasanya berbentuk count.
# 3. Usahakan tidak menggunakan pie chart kecuali ingin menampilkan persentase.

# %%
df_segment = df_clean.groupby('Segment')['Sales'].sum().reset_index()
display(df_segment)
df_segment['Percentage'] = df_segment['Sales']/df_segment['Sales'].sum() * 100
df_segment
# Out:
#        Segment        Sales
# 0     Consumer  757708.8613
# 1    Corporate  455519.3563
# 2  Home Office  251490.7545
#        Segment        Sales  Percentage
# 0     Consumer  757708.8613   51.730665
# 1    Corporate  455519.3563   31.099437
# 2  Home Office  251490.7545   17.169898

# %%
plt.figure(figsize=(10,5))

plt.pie(
    x = df_segment['Percentage'],
    labels= df_segment['Segment'],
    autopct='%.2f',
    explode=(0.001,0.05,0.5),
    shadow=True
)

plt.title('Proportion of Sales per Segement (%)')
plt.show()

# %% [markdown]
# ## **5. HEAT MAP**
# ---
# Catatan:
# 1. Warnan menunjukan intensitas dari nilai numerik
# 2. Biasanya semakin gelap warna, semakin besar nilainya.

# %%
df_corr = df_clean[['Sales','Quantity','Discount','Profit']].corr()
df_corr
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.223188 -0.046709  0.386171
# Quantity  0.223188  1.000000  0.008271  0.156463
# Discount -0.046709  0.008271  1.000000 -0.403055
# Profit    0.386171  0.156463 -0.403055  1.000000

# %%
plt.figure()
sns.heatmap(
    data = df_corr,
    annot = True,
    cmap = 'coolwarm'
    )
plt.show()

# %%
matrix = np.triu(df_corr)

plt.figure()
sns.heatmap(
    data = df_corr,
    annot = True,
    cmap = 'coolwarm',
    mask=matrix
    )
plt.show()
